# %% [markdown]
# # FedBuff Reproduction — Google Colab Notebook
#
# Reproduction of *Federated Learning with Buffered Asynchronous Aggregation* (Nguyen et al., AISTATS 2022).
#
# **How to use:** `File → Upload notebook` in [Google Colab](https://colab.research.google.com/), then run cells top to bottom. For GPU, use `Runtime → Change runtime type → GPU`.

# %% [markdown]
# ## 1. Verify GPU (optional)

# %%
# !nvidia-smi || echo 'No GPU — CPU runtime is fine, just slower.'

# %% [markdown]
# ## 2. Clone the repository
#
# Replace the URL below with your fork if needed.

# %%
# !git clone https://github.com/angelafoua/fedbuff.git
# %cd fedbuff

# %% [markdown]
# ## 3. Install dependencies

# %%
# !pip install torch torchvision numpy scipy tqdm tensorboard

# %% [markdown]
# ## 4. Quick smoke test — FedBuff on CIFAR-10
#
# Small concurrency / buffer for a fast end-to-end run.

# %%
# !python run_experiment.py --algorithm fedbuff --dataset cifar10 --concurrency 100 --K 10

# %% [markdown]
# ## 5. FedAvgM baseline

# %%
# !python run_experiment.py --algorithm fedavgm --dataset cifar10 --concurrency 100

# %% [markdown]
# ## 6. Full comparisons (long-running)
#
# These reproduce paper figures/tables and take a while — run only with GPU.

# %%
# Table 1 reproduction
# !python run_experiment.py --run_table1

# %%
# Figure 3 scalability experiment
# !python run_experiment.py --run_scalability

# %% [markdown]
# ## 7. TensorBoard (optional)

# %%
# %load_ext tensorboard
# %tensorboard --logdir runs
